# %%
import numpy as np
import pandas as pd
import seaborn as sb
fatality = pd.read_csv('fatality.csv')

# %%
fatality.head()
# Out:
#    Unnamed: 0  state  year    mrall   beertax   mlda jaild comserd    vmiles  \
# 0           1      1  1982  2.12836  1.539379  19.00    no      no  7.233887
# 1           2      1  1983  2.34848  1.788991  19.00    no      no  7.836348
# 2           3      1  1984  2.33643  1.714286  19.00    no      no  8.262990
# 3           4      1  1985  2.19348  1.652542  19.67    no      no  8.726917
# 4           5      1  1986  2.66914  1.609907  21.00    no      no  8.952854
#
#    unrate        perinc
# 0    14.4  10544.152344
# 1    13.7  10732.797852
# 2    11.1  11108.791016
# 3     8.9  11332.626953
# 4     9.8  11661.506836

# %%
fatality.groupby('year').mean()
# Out:
#       Unnamed: 0    state     mrall   beertax       mlda    vmiles    unrate  \
# year
# 1982       165.5  30.1875  2.089106  0.530273  20.031250  7.227225  9.266667
# 1983       166.5  30.1875  2.007846  0.532393  20.098958  7.384729  9.270833
# 1984       167.5  30.1875  2.017122  0.529590  20.180625  7.960133  7.233333
# 1985       168.5  30.1875  1.973671  0.516927  20.362708  7.740698  7.060417
# 1986       169.5  30.1875  2.065071  0.508664  20.623542  8.016382  6.918750
# 1987       170.5  30.1875  2.060696  0.495129  20.923542  8.290278  6.220833
# 1988       171.5  30.1875  2.069594  0.479815  20.968750  8.615830  5.456250
#
#             perinc
# year
# 1982  12998.259664
# 1983  13108.084819
# 1984  13582.509115
# 1985  13842.823039
# 1986  14186.296082
# 1987  14549.791667
# 1988  14893.527344

# %%
fatality.pivot_table('mrall', index='state', columns='year')
# Out:
# year      1982     1983     1984     1985     1986     1987     1988
# state
# 1      2.12836  2.34848  2.33643  2.19348  2.66914  2.71859  2.49391
# 4      2.49914  2.26738  2.82878  2.80201  3.07106  2.76728  2.70565
# 5      2.38405  2.39570  2.23785  2.26367  2.54323  2.67588  2.54697
# 6      1.86194  1.80672  1.94611  1.88128  1.94548  1.98966  1.90365
# 8      2.17448  2.05144  1.90596  1.79201  1.84630  1.79308  1.50560
# 9      1.64695  1.39490  1.48653  1.41147  1.40933  1.39832  1.49706
# 10     2.03333  1.81518  2.11726  1.67203  2.14850  2.26708  2.42424
# 12     2.53197  2.49768  2.54661  2.49164  2.42004  2.36131  2.49534
# 13     2.17484  2.26060  2.41356  2.27744  2.50820  2.56991  2.60643
# 16     2.61759  2.66194  2.42242  2.53731  2.57485  2.62525  2.56231
# 17     1.43840  1.32800  1.34265  1.32987  1.38170  1.43326  1.58171
# 18     1.75269  1.85605  1.68427  1.77123  1.88624  1.90743  1.98164
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
sb.set()  # use Seaborn styles

# %%
fatality.pivot_table('mrall', index='state', columns='year').plot()
plt.ylabel('fatality rate');
# Out:
# /srv/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
sb.violinplot("state", "mrall", data=fatality)
# Out:
# /srv/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
